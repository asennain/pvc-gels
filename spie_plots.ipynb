# %%
import matplotlib.pyplot as plt 
import pandas as pd 


# Variable Thickness
_4_cAvTh = pd.read_csv(
    r"C:\Users\asenn\OneDrive\School\Research\SPIE 2023\Data\COMBINED_AND_PROCESSED\constant_area_variable_thickness\_4_cAvTh.csv",
    )
 
_6_cAvTh = pd.read_csv(
    r"C:\Users\asenn\OneDrive\School\Research\SPIE 2023\Data\COMBINED_AND_PROCESSED\constant_area_variable_thickness\_6_cAvTh.csv",
    )

_8_cAvTh = pd.read_csv(
    r"C:\Users\asenn\OneDrive\School\Research\SPIE 2023\Data\COMBINED_AND_PROCESSED\constant_area_variable_thickness\_8_cAvTh.csv",
    )

_10_cAvTh = pd.read_csv(
    r"C:\Users\asenn\OneDrive\School\Research\SPIE 2023\Data\COMBINED_AND_PROCESSED\constant_area_variable_thickness\_10_cAvTh.csv",
    )



# Variable plasticizer
P2_cAvPL = pd.read_csv(
    r"C:\Users\asenn\OneDrive\School\Research\SPIE 2023\Data\COMBINED_AND_PROCESSED\variable_plasticizer_ratio\P2_cAvPL.csv",
    )

P4_cAvPL = pd.read_csv(
    r"C:\Users\asenn\OneDrive\School\Research\SPIE 2023\Data\COMBINED_AND_PROCESSED\variable_plasticizer_ratio\P4_cAvPL.csv",
    )

P6_cAvPL = pd.read_csv(
    r"C:\Users\asenn\OneDrive\School\Research\SPIE 2023\Data\COMBINED_AND_PROCESSED\variable_plasticizer_ratio\P6_cAvPL.csv",
    )

P8_cAvPL = pd.read_csv(
    r"C:\Users\asenn\OneDrive\School\Research\SPIE 2023\Data\COMBINED_AND_PROCESSED\variable_plasticizer_ratio\P8_cAvPL.csv",
    )


# Variable radial area flat and curved 
# Variable plasticizer
curved10_onestack = pd.read_csv(
    r"C:\Users\asenn\OneDrive\School\Research\SPIE 2023\Data\COMBINED_AND_PROCESSED\curvedandflat_variable_radial_area\curved10_onestack.csv",
    )

curved10_twostack = pd.read_csv(
    r"C:\Users\asenn\OneDrive\School\Research\SPIE 2023\Data\COMBINED_AND_PROCESSED\curvedandflat_variable_radial_area\curved10_twostack.csv",
    )

curved10_threestack = pd.read_csv(
    r"C:\Users\asenn\OneDrive\School\Research\SPIE 2023\Data\COMBINED_AND_PROCESSED\curvedandflat_variable_radial_area\curved10_threestack.csv",
    )

# Variable Area P4
P4_vA_8mm = pd.read_csv(
    r"C:\Users\asenn\OneDrive\School\Research\SPIE 2023\Data\COMBINED_AND_PROCESSED\variable_area_P4\P4_vA_8mm.csv",
    )

P4_vA_12_5mm = pd.read_csv(
    r"C:\Users\asenn\OneDrive\School\Research\SPIE 2023\Data\COMBINED_AND_PROCESSED\variable_area_P4\P4_vA_12_5mm.csv",
    )

P4_vA_16mm = pd.read_csv(
    r"C:\Users\asenn\OneDrive\School\Research\SPIE 2023\Data\COMBINED_AND_PROCESSED\variable_area_P4\P4_vA_16mm.csv",
    )

matrix_testing = pd.read_excel(
    r"C:\Users\asenn\OneDrive\School\Research\SPIE 2023\Data\Position Sensor\positionsensing(processed).xlsx",
    skiprows = 18,
    usecols=["Time", "CH111", "CH112", "CH113", "CH114"],
    )

display(matrix_testing)
# Out:
#           Time     CH111     CH112     CH113     CH114
# 0     0.000000 -2.328796 -1.194829 -0.670474 -1.482691
# 1     0.225316  0.058597 -0.592390 -1.534768 -0.851641
# 2     0.450180 -1.460247 -0.736338 -0.433568 -1.773966
# 3     0.675479 -0.185878 -0.964041 -1.751242 -0.713663
# 4     0.900310 -1.659174 -1.109423 -0.869484 -1.522961
# ..         ...       ...       ...       ...       ...
# 230  50.006003 -0.242863 -0.868553  0.141469 -1.595463
# 231  50.222758 -0.034206 -0.784747 -0.090109 -1.568451
# 232  50.439513 -0.062702 -0.791476 -0.013560 -1.240056
# 233  50.656249 -0.243160 -1.024621 -0.153599 -1.694539
# 234  50.872992 -0.113856 -0.927854 -0.349986 -1.724173
#
# [235 rows x 5 columns]

# %%
constant_area_variable_thickness = plt.figure()
plt.scatter('Load', 'Voltage', data = _4_cAvTh, marker='^', color='red')
plt.scatter('Load', 'Voltage', data = _6_cAvTh, marker='^', color='blue')
plt.scatter('Load', 'Voltage', data = _8_cAvTh, marker='^', color='green')
plt.scatter('Load', 'Voltage', data = _10_cAvTh, marker='^', color='blueviolet')
plt.legend(["1 mm", "1.3 mm", "1.7 mm","2 mm"], loc ="lower right", title = "Thickness")
plt.ylabel("Response (mv)")
plt.xlabel("Load (g)")

variable_plasticizer_ratio = plt.figure()
plt.scatter('Load', 'Voltage', data = P2_cAvPL, marker='^', color='red')
plt.scatter('Load', 'Voltage', data = P4_cAvPL, marker='^', color='blue')
plt.scatter('Load', 'Voltage', data = P6_cAvPL, marker='^', color='green')
plt.scatter('Load', 'Voltage', data = P8_cAvPL, marker='^', color='blueviolet')
plt.legend(["1:2", "1:4", "1:6","1:8"], loc = (.7, .22), title = "PVC to Plasticizer \n   Weight Ratio")
plt.ylabel("Response (mv)")
plt.xlabel("Load (g)")

curved_testing = plt.figure()
plt.scatter('Load', 'Voltage', data = curved10_onestack, marker='^', color='red')
plt.scatter('Load', 'Voltage', data = curved10_twostack, marker='^', color='blue')
plt.scatter('Load', 'Voltage', data = curved10_threestack, marker='^', color='green')
plt.legend(["100 mm²", "200 mm²", "300 mm²"], loc = (.73, .62), title = "Circumferential \n  Surface Area ")
plt.ylabel("Response (mv)")
plt.xlabel("Axial Load (g)")

var_area = plt.figure()
plt.scatter('Load', 'Voltage', data = P4_vA_8mm, marker='^', color='red')
plt.scatter('Load', 'Voltage', data = P4_vA_12_5mm, marker='^', color='blue')
plt.scatter('Load', 'Voltage', data = P4_vA_16mm, marker='^', color='green')
plt.legend(["8 mm²", "12.5 mm²", "16 mm²"], loc = (.65, .62), title = "Planar Surface Area ")
plt.ylabel("Response (mv)")
plt.xlabel("Load (g)")

position_testing = plt.figure()
plt.plot('Time', 'CH111', data = matrix_testing, color = 'red')
plt.plot('Time', 'CH112', data = matrix_testing, color = 'blue')
plt.plot('Time', 'CH113', data = matrix_testing, color = 'green')
plt.plot('Time', 'CH114', data = matrix_testing, color = 'orange')
plt.ylabel("Response (mv)")
plt.xlabel("Time (s)")
plt.legend(["Junction 1", "Junction 2", "Junction 3", "Junction 4"], loc = (.7, .15))
